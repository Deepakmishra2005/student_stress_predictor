# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("student-lifestyle-and-stress-dataset.csv")
data
# Out:
#       Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0           school     6.868702     1.711722            3.176942         NaN
# 1           school     8.519088     3.251084            3.880787   93.978465
# 2          college     4.498770     6.306885            2.936172   64.421253
# 3           school     8.591223     2.384922            5.222832   81.868960
# 4          college     5.329293     9.345179            7.815869   85.847982
# ...            ...          ...          ...                 ...         ...
# 25495      college     7.803069     7.328193            2.018277   75.435607
# 25496       school     6.734607     2.680109            3.355559   63.387386
# 25497      college     7.701671     2.631250            2.948252   79.818930
# 25498       school     5.903426     3.450424            6.823894   96.680773
# 25499      college     7.419726     6.442748            3.356066   81.452460
#
# ...

# %%
data.head()
# Out:
#   Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0       school     6.868702     1.711722            3.176942         NaN
# 1       school     8.519088     3.251084            3.880787   93.978465
# 2      college     4.498770     6.306885            2.936172   64.421253
# 3       school     8.591223     2.384922            5.222832   81.868960
# 4      college     5.329293     9.345179            7.815869   85.847982
#
#    Exam_Pressure  Family_Support  Month  Stress_Level
# 0            8.0             7.0    2.0             1
# 1            6.0             4.0    3.0             1
# 2            7.0             1.0   12.0             1
# 3            2.0             7.0    7.0             0
# 4            5.0             6.0   10.0             1

# %%
data.tail()
# Out:
#       Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 25495      college     7.803069     7.328193            2.018277   75.435607
# 25496       school     6.734607     2.680109            3.355559   63.387386
# 25497      college     7.701671     2.631250            2.948252   79.818930
# 25498       school     5.903426     3.450424            6.823894   96.680773
# 25499      college     7.419726     6.442748            3.356066   81.452460
#
#        Exam_Pressure  Family_Support  Month  Stress_Level
# 25495            5.0             1.0   12.0             0
# 25496            8.0             9.0    2.0             1
# 25497            4.0             3.0    4.0             1
# 25498            2.0             6.0    6.0             0
# 25499            9.0             5.0    6.0             1

# %%
print("Rows:",data.shape[0])
print("Columns:",data.shape[1])
# Out:
# Rows: 25500
# Columns: 9

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25500 entries, 0 to 25499
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_Type        24248 non-null  str
#  1   Sleep_Hours         24167 non-null  float64
#  2   Study_Hours         24223 non-null  float64
#  3   Social_Media_Hours  24188 non-null  float64
#  4   Attendance          24195 non-null  float64
#  5   Exam_Pressure       24230 non-null  float64
#  6   Family_Support      24209 non-null  float64
#  7   Month               24186 non-null  float64
#  8   Stress_Level        25500 non-null  int64
# dtypes: float64(7), int64(1), str(1)
# memory usage: 1.9 MB

# %%
data.describe()
# Out:
#         Sleep_Hours   Study_Hours  Social_Media_Hours    Attendance  \
# count  24167.000000  24223.000000        24188.000000  24195.000000
# mean       6.458948      4.696477            3.555614     81.270961
# std        1.504228      2.240148            1.901528     12.052045
# min        2.008586     -1.433434            0.000040     -5.000000
# 25%        5.438360      3.078230            2.152249     73.738894
# 50%        6.542566      4.538138            3.500709     81.942959
# 75%        7.531571      6.135670            4.864312     90.106859
# max        9.997527     22.444460            9.962134    120.000000
#
#        Exam_Pressure  Family_Support         Month  Stress_Level
# count   24230.000000    24209.000000  24186.000000  25500.000000
# mean        5.369748        5.798298      6.500992      0.299882
# std         2.394003        2.232371      3.455308      0.458215
# min         1.000000        1.000000      1.000000      0.000000
# ...

# %%
data['Student_Type'].notnull().sum()
# Out:
# np.int64(24248)

# %%
data.describe(include="object")
# Out:
#        Student_Type
# count         24248
# unique            3
# top         college
# freq          13391

# %%
data.describe(include="all")
# Out:
#        Student_Type   Sleep_Hours   Study_Hours  Social_Media_Hours  \
# count         24248  24167.000000  24223.000000        24188.000000
# unique            3           NaN           NaN                 NaN
# top         college           NaN           NaN                 NaN
# freq          13391           NaN           NaN                 NaN
# mean            NaN      6.458948      4.696477            3.555614
# std             NaN      1.504228      2.240148            1.901528
# min             NaN      2.008586     -1.433434            0.000040
# 25%             NaN      5.438360      3.078230            2.152249
# 50%             NaN      6.542566      4.538138            3.500709
# 75%             NaN      7.531571      6.135670            4.864312
# max             NaN      9.997527     22.444460            9.962134
#
#           Attendance  Exam_Pressure  Family_Support         Month  \
# count   24195.000000   24230.000000    24209.000000  24186.000000
# ...

# %%
data.isnull().sum()
# Out:
# Student_Type          1252
# Sleep_Hours           1333
# Study_Hours           1277
# Social_Media_Hours    1312
# Attendance            1305
# Exam_Pressure         1270
# Family_Support        1291
# Month                 1314
# Stress_Level             0
# dtype: int64

# %%
data.isnull().sum()/len(data)*100
# Out:
# Student_Type          4.909804
# Sleep_Hours           5.227451
# Study_Hours           5.007843
# Social_Media_Hours    5.145098
# Attendance            5.117647
# Exam_Pressure         4.980392
# Family_Support        5.062745
# Month                 5.152941
# Stress_Level          0.000000
# dtype: float64

# %%
missing=data.isnull().sum()
missing_percentage=(missing/len(data))*100
missing_table=pd.DataFrame({
    "Missing Values":missing,
    "Percentage":missing_percentage
})
missing_table.sort_values(by="Percentage",ascending=False)
# Out:
#                     Missing Values  Percentage
# Sleep_Hours                   1333    5.227451
# Month                         1314    5.152941
# Social_Media_Hours            1312    5.145098
# Attendance                    1305    5.117647
# Family_Support                1291    5.062745
# Study_Hours                   1277    5.007843
# Exam_Pressure                 1270    4.980392
# Student_Type                  1252    4.909804
# Stress_Level                     0    0.000000

# %%
data.duplicated().sum()
# Out:
# np.int64(24)

# %%
data[data.duplicated()]
# Out:
#           Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  \
# 1126           college     5.568207          NaN            5.909244
# 4072           college     8.148713          NaN            6.784068
# 4790           college     4.277435          NaN            3.655623
# 10050           school     8.478522          NaN            6.113217
# 10182           school     8.036559          NaN            2.692154
# 10862           school     5.172729          NaN            3.635343
# 12383          college     8.560583          NaN            4.222640
# 14020          college     5.474364          NaN            1.967293
# 14272           school     8.796297          NaN            2.591195
# 14603  working_student     4.564705          NaN            3.151107
# 14669           school     7.462920          NaN            2.996539
# 15927  working_student     4.603725          NaN            5.419738
# 16587           school     7.223621          NaN                 NaN
# ...

# %%
data.dtypes
# Out:
# Student_Type              str
# Sleep_Hours           float64
# Study_Hours           float64
# Social_Media_Hours    float64
# Attendance            float64
# Exam_Pressure         float64
# Family_Support        float64
# Month                 float64
# Stress_Level            int64
# dtype: object

# %%
data.dtypes.value_counts()
# Out:
# float64    7
# str        1
# int64      1
# Name: count, dtype: int64

# %%
categorical_columns= data.select_dtypes(include= ["object"]).columns
for column in categorical_columns:
    print("="*50)
    print("Column:", column)
    print ("Unique Values :", data[column].unique())
    print ("Total Unique :", data[column].nunique())
# Out:
# ...
# Column: Student_Type
# Unique Values : <ArrowStringArray>
# ['school', 'college', 'working_student', nan]
# Length: 4, dtype: str
# Total Unique : 3

# %%
numerical_columns=data.select_dtypes(include=['int64','float64']).columns
print(numerical_columns)
# Out:
# Index(['Sleep_Hours', 'Study_Hours', 'Social_Media_Hours', 'Attendance',
#        'Exam_Pressure', 'Family_Support', 'Month', 'Stress_Level'],
#       dtype='str')

# %%
for column in numerical_columns:
    print("="*50)
    print(column)
    print ("Minimum :", data[column].min())
    print ("Maximum:", data[column].max())
# Out:
# ...
# Sleep_Hours
# Minimum : 2.008585834049811
# Maximum: 9.997527332954435
# ...
# Study_Hours
# Minimum : -1.4334339503800193
# Maximum: 22.44445955751421
# ...
# Social_Media_Hours
# Minimum : 3.99504250175875e-05
# Maximum: 9.962134492424031
# ...
# Attendance
# Minimum : -5.0
# Maximum: 120.0
# ...
# Exam_Pressure
# Minimum : 1.0
# Maximum: 10.0
# ...
# Family_Support
# Minimum : 1.0
# Maximum: 10.0
# ...
# Month
# Minimum : 1.0
# Maximum: 12.0
# ...
# Stress_Level
# Minimum : 0
# Maximum: 1

# %%
data.shape
# Out:
# (25500, 9)

# %%
print("Duplicate Rows:",data.duplicated().sum())
# Out:
# Duplicate Rows: 24

# %%
data.drop_duplicates(inplace=True)

# %%
print("Duplicate Rows:",data.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
data.shape
# Out:
# (25476, 9)

# %%
data.isnull().sum()
# Out:
# Student_Type          1251
# Sleep_Hours           1333
# Study_Hours           1253
# Social_Media_Hours    1310
# Attendance            1304
# Exam_Pressure         1270
# Family_Support        1290
# Month                 1314
# Stress_Level             0
# dtype: int64

# %%
for column in numerical_columns:
    data[column]=data[column].fillna(data[column].median())

# %%
for column in categorical_columns:
    data[column]=data[column].fillna(data[column].mode()[0])

# %%
data.isnull().sum()
# Out:
# Student_Type          0
# Sleep_Hours           0
# Study_Hours           0
# Social_Media_Hours    0
# Attendance            0
# Exam_Pressure         0
# Family_Support        0
# Month                 0
# Stress_Level          0
# dtype: int64

# %%
data.shape
# Out:
# (25476, 9)

# %%
for column in categorical_columns:
    data[column]=data[column].str.strip()

# %%
for column in categorical_columns:
    data[column]=data[column].str.title()

# %%
plt.figure(figsize=(15,8))
for i, column in enumerate(numerical_columns,1):
    plt.subplot(3,4,i)
    sns.boxplot(x=data[column])
    plt.title(column)
plt.tight_layout()
plt.show()

# %%
for column in numerical_columns:
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR=Q3-Q1
    lower = Q1-1.5 * IQR
    upper = Q3 + 1.5*IQR
    outliers = data[(data[column] < lower) | (data[column] > upper)]
    print(f"{column}: {len(outliers)} outliers")
# Out:
# Sleep_Hours: 162 outliers
# Study_Hours: 229 outliers
# Social_Media_Hours: 118 outliers
# Attendance: 232 outliers
# Exam_Pressure: 0 outliers
# Family_Support: 0 outliers
# Month: 0 outliers
# Stress_Level: 0 outliers

# %%
data.hist(figsize=(15,10))
plt.tight_layout()
plt.show()

# %%
for column in categorical_columns:
    plt.figure(figsize=(8,4))
    sns.countplot(data=data,x=column)
    plt.xticks(rotation=45)
    plt.title(column)
    plt.show()

# %%
print(data.columns)
# Out:
# Index(['Student_Type', 'Sleep_Hours', 'Study_Hours', 'Social_Media_Hours',
#        'Attendance', 'Exam_Pressure', 'Family_Support', 'Month',
#        'Stress_Level'],
#       dtype='str')

# %%
data.drop("Month",axis=1,inplace=True)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(
    data.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm"
)
plt.title("Correlation Heatmap")
plt.show()

# %%
data.columns
# Out:
# Index(['Student_Type', 'Sleep_Hours', 'Study_Hours', 'Social_Media_Hours',
#        'Attendance', 'Exam_Pressure', 'Family_Support', 'Stress_Level'],
#       dtype='str')

# %%
X=data.drop(["Stress_Level"],axis=1)
y=data["Stress_Level"]

# %%
print("Feature Shape:",X.shape)
print("Target Shape:",y.shape)
# Out:
# Feature Shape: (25476, 7)
# Target Shape: (25476,)

# %% [markdown]
# ## Data Preprocessing

# %%
X.dtypes
# Out:
# Student_Type              str
# Sleep_Hours           float64
# Study_Hours           float64
# Social_Media_Hours    float64
# Attendance            float64
# Exam_Pressure         float64
# Family_Support        float64
# dtype: object

# %%
numerical_columns=X.select_dtypes(include=["int64","float64"]).columns
categorical_columns=X.select_dtypes(include=["object"]).columns

# %%
print(numerical_columns)
print(categorical_columns)
# Out:
# Index(['Sleep_Hours', 'Study_Hours', 'Social_Media_Hours', 'Attendance',
#        'Exam_Pressure', 'Family_Support'],
#       dtype='str')
# Index(['Student_Type'], dtype='str')

# %%
X["Student_Type"].unique()
# Out:
# <ArrowStringArray>
# ['School', 'College', 'Working_Student']
# Length: 3, dtype: str

# %% [markdown]
# ## Categorical Column Encoding

# %%
X["Student_Type"]=X["Student_Type"].map({'School':0,'College':1,'Working_Student':2})

# %%
X.head()
# Out:
#    Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0             0     6.868702     1.711722            3.176942   81.941554
# 1             0     8.519088     3.251084            3.880787   93.978465
# 2             1     4.498770     6.306885            2.936172   64.421253
# 3             0     8.591223     2.384922            5.222832   81.868960
# 4             1     5.329293     9.345179            7.815869   85.847982
#
#    Exam_Pressure  Family_Support
# 0            8.0             7.0
# 1            6.0             4.0
# 2            7.0             1.0
# 3            2.0             7.0
# 4            5.0             6.0

# %%
X.shape
# Out:
# (25476, 7)

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42,stratify=y)

# %%
print("Training Features:",X_train.shape)
print("Training Features:",X_test.shape)
print("Training Target:",y_train.shape)
print("Testing Target:",y_test.shape)
# Out:
# Training Features: (20380, 7)
# Training Features: (5096, 7)
# Training Target: (20380,)
# Testing Target: (5096,)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Create Scaler object

# %%
scaler=StandardScaler()

# %% [markdown]
# ## Scale Training data

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
X_train = pd.DataFrame(X_train,columns=X.columns)

# %%
X_test = pd.DataFrame(X_test,columns=X.columns)

# %%
X_train
# Out:
#        Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0         -1.465229     0.478909    -1.255902            1.030010    0.325200
# 1          0.069034     0.294439    -0.067402            0.506328   -1.402287
# 2         -1.465229     0.056968    -0.310020            2.117781   -0.689960
# 3          0.069034    -0.636523    -0.556749           -0.029219    0.095262
# 4          0.069034     0.185215    -0.867024            0.006217    0.180564
# ...             ...          ...          ...                 ...         ...
# 20375     -1.465229     0.596961    -1.312807            0.083179    1.155577
# 20376      1.603297    -0.183182    -1.608832            0.213113   -1.020680
# 20377      0.069034    -1.576376    -0.067402           -0.601968    0.751795
# 20378      0.069034    -0.955543    -0.577218           -1.479662   -2.235722
# 20379      0.069034    -0.824038     0.711592            0.072709   -0.750249
#
# ...

# %%
X_test
# Out:
#       Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0         0.069034     0.540941     0.302700           -1.479953   -0.713956
# 1        -1.465229     1.712262    -0.861254            0.612861    0.208087
# 2         1.603297    -0.351314     0.105498           -0.348486   -0.734340
# 3        -1.465229     1.632603    -1.151831            0.966235    0.855641
# 4         1.603297     1.968383     1.596166            1.076597    0.737200
# ...            ...          ...          ...                 ...         ...
# 5091      0.069034     0.949679     0.026417           -0.799261    0.603539
# 5092     -1.465229     0.851810    -0.067402            2.811751    0.222550
# 5093      1.603297    -0.403427     0.429115           -0.946566   -0.433519
# 5094      0.069034     0.240309    -1.265679            0.796735    1.259765
# 5095      0.069034    -1.020773     0.517816           -1.865254    0.955656
#
#       Exam_Pressure  Family_Support
# ...

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %% [markdown]
# ## Model Selection

# %% [markdown]
# ##  Classification Algorithms

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier

# %%
lr_model= LogisticRegression(random_state=42)
dt_model= DecisionTreeClassifier(random_state=42)
rf_model= RandomForestClassifier(random_state=42)
knn_model= KNeighborsClassifier()
svm_model= SVC(random_state=42)
gb_model= GradientBoostingClassifier(random_state=42)

# %% [markdown]
# ## Model Training

# %%
lr_model.fit(X_train,y_train)
dt_model.fit(X_train,y_train)
rf_model.fit(X_train,y_train)
knn_model.fit(X_train,y_train)
svm_model.fit(X_train,y_train)
gb_model.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
lr_pred = lr_model.predict(X_test)
dt_pred = dt_model.predict(X_test)
rf_pred = rf_model.predict(X_test)
knn_pred = knn_model.predict(X_test)
svm_pred = svm_model.predict(X_test)
gb_pred = gb_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print("="*60)
print("Logistic Regression")
print("Accuracy:",accuracy_score(y_test,lr_pred))

print("="*60)
print("Decision Tree")
print("Accuracy:",accuracy_score(y_test,dt_pred))

print("="*60)
print("Random Forest")
print("Accuracy:",accuracy_score(y_test,rf_pred))

print("="*60)
print("KNN")
print("Accuracy:",accuracy_score(y_test,knn_pred))

print("="*60)
print("Support Vector Machine")
print("Accuracy:",accuracy_score(y_test,svm_pred))

print("="*60)
print("Gradient Boosting")
print("Accuracy:",accuracy_score(y_test,gb_pred))
# Out:
# ...
# Logistic Regression
# Accuracy: 0.820054945054945
# ...
# Decision Tree
# Accuracy: 0.743916797488226
# ...
# Random Forest
# Accuracy: 0.8122056514913658
# ...
# KNN
# Accuracy: 0.7868916797488226
# ...
# Support Vector Machine
# Accuracy: 0.8188775510204082
# ...
# Gradient Boosting
# Accuracy: 0.8194662480376766

# %%
results=pd.DataFrame({
    "Model":[
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "KNN",
        "SVM",
        "Gradient Boosting"
    ],
    "Accuracy":[
        accuracy_score(y_test,lr_pred),
        accuracy_score(y_test,dt_pred),
        accuracy_score(y_test,rf_pred),
        accuracy_score(y_test,knn_pred),
        accuracy_score(y_test,svm_pred),
        accuracy_score(y_test,gb_pred)
    ]
})
results.sort_values(by="Accuracy",ascending=False,inplace=True)
results
# Out:
#                  Model  Accuracy
# 0  Logistic Regression  0.820055
# 5    Gradient Boosting  0.819466
# 4                  SVM  0.818878
# 2        Random Forest  0.812206
# 3                  KNN  0.786892
# 1        Decision Tree  0.743917

# %%
from sklearn.model_selection import cross_val_score

# %%
score1=cross_val_score(lr_model,X_train,y_train,cv=5,scoring="accuracy")
#score2=cross_val_score(dt_model,X_train,y_train,cv=5,scoring="accuracy")
#score3=cross_val_score(rf_model,X_train,y_train,cv=5,scoring="accuracy")
#score4=cross_val_score(knn_model,X_train,y_train,cv=5,scoring="accuracy")
#score5=cross_val_score(svm_model,X_train,y_train,cv=5,scoring="accuracy")
#score6=cross_val_score(gb_model,X_train,y_train,cv=5,scoring="accuracy")

# %%
print(score1)
#print(score2)
#print(score3)
#print(score4)
#print(score5)
#print(score6)
# Out:
# [0.81452404 0.81820412 0.80299313 0.80863592 0.81943081]

# %%
import joblib

# %%
joblib.dump(lr_model,"student_stress_model.pkl")
# Out:
# ['student_stress_model.pkl']

# %%
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
print(X.columns)
# Out:
# Index(['Student_Type', 'Sleep_Hours', 'Study_Hours', 'Social_Media_Hours',
#        'Attendance', 'Exam_Pressure', 'Family_Support'],
#       dtype='str')

# %%
data.head(1)
# Out:
#   Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0       School     6.868702     1.711722            3.176942   81.941554
#
#    Exam_Pressure  Family_Support  Stress_Level
# 0            8.0             7.0             1

# %%
sample=X_train.loc[[13]]
print(sample)
print("Actual:",y_train.loc[123])
print("Predicted:",lr_model.predict(sample))
print("Probability:",lr_model.predict_proba(sample))
X_train.head()
# Out:
#     Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 13     -1.465229     1.759856     2.574221           -1.023341    0.770523
#
#     Exam_Pressure  Family_Support
# 13      -1.011225       -0.380131
# Actual: 0
# Predicted: [0]
# Probability: [[0.91055311 0.08944689]]
#    Student_Type  Sleep_Hours  Study_Hours  Social_Media_Hours  Attendance  \
# 0     -1.465229     0.478909    -1.255902            1.030010    0.325200
# 1      0.069034     0.294439    -0.067402            0.506328   -1.402287
# 2     -1.465229     0.056968    -0.310020            2.117781   -0.689960
# 3      0.069034    -0.636523    -0.556749           -0.029219    0.095262
# 4      0.069034     0.185215    -0.867024            0.006217    0.180564
#
#    Exam_Pressure  Family_Support
# 0       1.131682       -0.380131
# 1       1.560264        1.466828
# 2       0.274519        0.543349
# 3       0.703101       -0.380131
# 4       1.560264        0.081609

# %%
new_student=pd.DataFrame({
    "Student_Type":[-1.465229],
    "Sleep_Hours":[1.759856],
    "Study_Hours":[2.574221],
    "Social_Media_Hours":[-1.023341],
    "Attendance":[0.770523],
    "Exam_Pressure":[-1.011225],
    "Family_Support":[ -0.380131 ]
})

# %%
new_student_scaled=scaler.transform(new_student)

# %%
prediction=lr_model.predict(new_student_scaled)

# %%
print("Predicted
